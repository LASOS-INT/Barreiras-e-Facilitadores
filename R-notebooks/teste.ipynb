# %%
#install.packages("here")
library(here, help, pos = 2, lib.loc = NULL)
source(here('Modules','modules.R'))
#install_all_packages()
load_library_packages()
# Out:
# Warning message:
# "package 'here' was built under R version 4.1.1"
# here() starts at C:/Users/maria/Desktop/Programacao/IC/projetos/Barreiras-e-Facilitadores
#
# Warning message:
# "package 'ggplot2' was built under R version 4.1.1"
# Warning message:
# "package 'cowplot' was built under R version 4.1.1"
# Warning message:
# "package 'randomForest' was built under R version 4.1.1"
# randomForest 4.6-14
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: 'randomForest'
#
#
# The following object is masked from 'package:ggplot2':
#
#     margin
#
#
# Warning message:
# "package 'caret' was built under R version 4.1.1"
# Carregando pacotes exigidos: lattice
#
# Warning message:
# "package 'lattice' was built under R version 4.1.1"
# Warning message:
# "package 'rpart.plot' was built under R version 4.1.1"
# Carregando pacotes exigidos: rpart
#
# Warning message:
# "package 'readxl' was built under R version 4.1.2"
# Warning message:
# ...

# %%
dados <- data.frame(x=c(1, 2, 1, 1.5, 4, 4, 5), y=c(1, 2, 2, 1.5,  3, 5, 5), z=c(1, 1, 1, 1, 2, 2, 2))

ggplot(dados, aes(x, y, size=4, colour=z)) + geom_point()
# Out:
# plot without title

# %%
set.seed(2)
tsne <- Rtsne(dados, dims = 2, perplexity=2, check_duplicates = FALSE, verbose=TRUE)
# Out:
# Performing PCA
# Read the 7 x 3 data matrix successfully!
# OpenMP is working. 1 threads.
# Using no_dims = 2, perplexity = 2.000000, and theta = 0.500000
# Computing input similarities...
# Building tree...
# Done in 0.01 seconds (sparsity = 0.857143)!
# Learning embedding...
# Iteration 50: error is 53.420555 (50 iterations in 0.05 seconds)
# Iteration 100: error is 51.066740 (50 iterations in 0.01 seconds)
# Iteration 150: error is 45.445931 (50 iterations in 0.00 seconds)
# Iteration 200: error is 60.080838 (50 iterations in 0.01 seconds)
# Iteration 250: error is 66.138839 (50 iterations in 0.00 seconds)
# Iteration 300: error is 1.097868 (50 iterations in 0.00 seconds)
# Iteration 350: error is 0.870504 (50 iterations in 0.01 seconds)
# Iteration 400: error is 0.649843 (50 iterations in 0.00 seconds)
# Iteration 450: error is 0.579459 (50 iterations in 0.00 seconds)
# Iteration 500: error is 0.400020 (50 iterations in 0.00 seconds)
# ...

# %%
metadata <- data.frame(sample_id = rownames(dados),
                       colour = dados$z )
tsne_df <- data.frame(
    x = tsne$Y[,1],
    y = tsne$Y[,2],
    colour = metadata$colour)

ggplot(tsne_df, aes(x, y, colour = colour, size=4)) + geom_point()
# Out:
# plot without title
